# %%
import pandas as pd
companies = pd.read_csv("companies.csv")
companies
# Out:
#          Company                Department  NumOfMen  NumOfFem
# 0          Avamm                Accounting        63         9
# 1     Browsezoom                  Training        13        89
# 2        Tagchat                     Legal        87        48
# 3          Skyba           Human Resources        60        63
# 4          Lazzy  Research and Development        11        40
# 5   Thoughtworks        Product Management        41        90
# 6     Jabbercube      Business Development        31        68
# 7        Dabtype                     Legal        54        78
# 8       Fanoodle                  Services        16        43
# 9      Linklinks                Accounting        34         4
# 10    Fivebridge                  Training        55        62
# 11         Kazio                     Sales        75        33
# 12      Snaptags                 Marketing        12        19
# 13          Yotz                   Support        65        69
# ...

# %%
companies["NumOfMen"].sum()
# Out:
# 929

# %%
companies["NumOfFem"].mean()
